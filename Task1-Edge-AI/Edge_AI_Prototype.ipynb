# %% [markdown]
# Part 1: # Model training (Lightweight classifier)

# %%
# Setup

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Paths
data_dir = '/content/Image_Dataset/TrashType_Image_Dataset/'

# Image preprocessing
img_size = (128, 128)
batch_size = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    subset='training',
    class_mode='categorical'
)

val_data = datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    subset='validation',
    class_mode='categorical'
)

num_classes = train_data.num_classes
# Out:
# Found 2024 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.

# %%
# Model architecture (MobileNetV2)

base_model = tf.keras.applications.MobileNetV2(
    input_shape=(128, 128, 3),
    include_top=False,
    weights='imagenet'
)

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(train_data, validation_data=val_data, epochs=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.5783 - loss: 1.2326 - val_accuracy: 0.3459 - val_loss: 3.3856
# Epoch 2/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.8393 - loss: 0.4965 - val_accuracy: 0.3161 - val_loss: 6.3836
# Epoch 3/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 126s 2s/step - accuracy: 0.8822 - loss: 0.4034 - val_accuracy: 0.1988 - val_loss: 12.0115
# Epoch 4/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9035 - loss: 0.2901 - val_accuracy: 0.3241 - val_loss: 5.2218
# Epoch 5/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9078 - loss: 0.2674 - val_accuracy: 0.2008 - val_loss: 6.2778
# Epoch 6/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9302 - loss: 0.2357 - val_accuracy: 0.2107 - val_loss: 9.0078
# Epoch 7/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.8888 - loss: 0.3357 - val_accuracy: 0.2485 - val_loss: 6.3373
# Epoch 8/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9374 - loss: 0.1731 - val_accuracy: 0.2684 - val_loss: 7.3896
# Epoch 9/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9517 - loss: 0.1475 - val_accuracy: 0.4354 - val_loss: 3.2015
# Epoch 10/10
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 127s 2s/step - accuracy: 0.9723 - loss: 0.0893 - val_accuracy: 0.2187 - val_loss: 6.7358

# %% [markdown]
# Part 2: Convert to TensorFlow Lite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open('/content/model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmp8k953avs'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   136580326893008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326893584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326896272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326895888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326894736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326896464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326894928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326897040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326896656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326894544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326893200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326898192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326898384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326895120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326895696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326898960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311598480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311598672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580326899344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311597520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311597136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311599824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311600016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311599248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311597328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311598864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311598096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311598288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311599440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311600976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311600400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311600592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311600784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311599632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311601936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311601360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311601552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311601744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311597904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311602896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311603280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311603472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311602512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311603088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311604048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311604432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311604624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311603664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311604240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311605200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311602704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311604816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311605008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311602128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311606160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311605584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311605776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311605968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311602320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311607120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311606544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311606736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311606928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311603856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311608080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311607504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311607696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311607888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311605392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311609040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311608464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311608656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311608848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311606352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311610000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311609424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311609616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311609808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311607312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311610960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311610384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311610576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311610768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311608272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311611920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311611344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311611536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311611728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311609232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311612880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311612304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311610192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311613072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311612496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311613264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311612688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301947344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311611152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580311612112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301946960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301948112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301948304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301947728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301949264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301948688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301948880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301949072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301947152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301950224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301949648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301949840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301950032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301947536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301951184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301950608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301950800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301950992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301948496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301952144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301951568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301951760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301951952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301949456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301953104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301952528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301952720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301952912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301950416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301954064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301953488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301953680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301953872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301951376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301955024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301954448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301954640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301952336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301955984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301955408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301955600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301955792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301953296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301956944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301956368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301956560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301956752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301954256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301957904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301957328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301957520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301957712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301955216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301958864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301958288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301958480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301958672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301956176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301959824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301959248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301959440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301959632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301957136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301960784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301960208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301960400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301960592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301958096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301961744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301961168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301961360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301961552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301959056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301962704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301962128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301960016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301962896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301962320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301963088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301962512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302849232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302849424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301960976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580301961936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302848080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302848848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302849040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302848656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302850384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302849808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302850000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302850192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302848272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302851344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302850768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302850960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302851152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302848464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302852304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302851728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302851920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302852112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302849616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302853264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302852688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302852880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302853072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302850576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302854224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302853648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302853840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302854032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302851536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302855184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302854608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302854800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302854992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302852496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302856144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302855568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302855760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302855952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302853456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302857104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302856528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302856720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302856912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302854416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302858064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302857488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302857680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302857872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302855376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302859024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302858448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302858640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302858832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302856336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302859984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302859408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302859600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302859792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302857296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302860944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302860368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302860560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302860752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302858256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302861904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302861328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302861520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302861712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302859216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302862864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302862288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302862480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302862672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302860176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302863824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302861136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580302863632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136583053642640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136580299932112: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# Part 3: Test TFLite model

# %%
import os
from PIL import Image
import numpy as np

interpreter = tf.lite.Interpreter(model_path='/content/model.tflite')
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

test_folder = '/content/Image_Dataset/TrashType_Image_Dataset/'
class_names = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

results = []
for class_dir in os.listdir(test_folder):
    class_path = os.path.join(test_folder, class_dir)
    if not os.path.isdir(class_path):
        continue

    for filename in os.listdir(class_path):
        if filename.lower().endswith(('.jpg', '.png')):
            img_path = os.path.join(class_path, filename)
            try:
                image = Image.open(img_path).convert('RGB').resize((128, 128))
                image = np.array(image) / 255.0
                image = np.expand_dims(image, axis=0).astype(np.float32)

                interpreter.set_tensor(input_details[0]['index'], image)
                interpreter.invoke()
                output = interpreter.get_tensor(output_details[0]['index'])

                predicted_class = np.argmax(output)
                confidence = np.max(output)
                predicted_label = class_names[predicted_class]

                results.append({
                    'filename': filename,
                    'true_label': class_dir,
                    'predicted_label': predicted_label,
                    'confidence': round(confidence, 2)
                })

            except Exception as e:
                print(f"Error processing {img_path}: {e}")

# Display results
for r in results:
    print(f"{r['filename']} | True: {r['true_label']} → Predicted: {r['predicted_label']} ({r['confidence']})")
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# cardboard_148.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_061.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_130.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_386.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_323.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_204.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_036.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_154.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_022.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_017.jpg | True: cardboard → Predicted: cardboard (0.5400000214576721)
# cardboard_383.jpg | True: cardboard → Predicted: trash (0.9599999785423279)
# cardboard_060.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_284.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_196.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_322.jpg | True: cardboard → Predicted: metal (0.5400000214576721)
# cardboard_324.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_291.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_233.jpg | True: cardboard → Predicted: metal (0.9200000166893005)
# cardboard_113.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_026.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_167.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_340.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_034.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_392.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_073.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_102.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_077.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_129.jpg | True: cardboard → Predicted: metal (0.8899999856948853)
# cardboard_038.jpg | True: cardboard → Predicted: trash (0.9800000190734863)
# cardboard_157.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_006.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_049.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_194.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_115.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_317.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_302.jpg | True: cardboard → Predicted: metal (0.9599999785423279)
# cardboard_366.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_248.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_313.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_153.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_288.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_255.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_058.jpg | True: cardboard → Predicted: trash (0.75)
# cardboard_175.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_369.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_225.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_260.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_250.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_169.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_103.jpg | True: cardboard → Predicted: trash (0.5299999713897705)
# cardboard_281.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_394.jpg | True: cardboard → Predicted: cardboard (0.6200000047683716)
# cardboard_275.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_328.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_052.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_078.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_346.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_135.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_005.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_301.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_222.jpg | True: cardboard → Predicted: metal (0.9200000166893005)
# cardboard_164.jpg | True: cardboard → Predicted: metal (0.9599999785423279)
# cardboard_278.jpg | True: cardboard → Predicted: metal (0.9399999976158142)
# cardboard_072.jpg | True: cardboard → Predicted: metal (0.8199999928474426)
# cardboard_079.jpg | True: cardboard → Predicted: metal (0.7799999713897705)
# cardboard_205.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_112.jpg | True: cardboard → Predicted: metal (0.9100000262260437)
# cardboard_134.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_031.jpg | True: cardboard → Predicted: metal (0.7799999713897705)
# cardboard_032.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_097.jpg | True: cardboard → Predicted: trash (0.550000011920929)
# cardboard_075.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_040.jpg | True: cardboard → Predicted: metal (0.9300000071525574)
# cardboard_192.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_329.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_246.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_140.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_393.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_082.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_232.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_144.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_042.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_200.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_387.jpg | True: cardboard → Predicted: metal (0.949999988079071)
# cardboard_306.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_380.jpg | True: cardboard → Predicted: metal (0.7699999809265137)
# cardboard_108.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_397.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_007.jpg | True: cardboard → Predicted: metal (0.9599999785423279)
# cardboard_121.jpg | True: cardboard → Predicted: metal (0.550000011920929)
# cardboard_286.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_105.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_251.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_202.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_263.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_159.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_178.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_212.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_230.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_335.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_221.jpg | True: cardboard → Predicted: metal (0.6800000071525574)
# cardboard_298.jpg | True: cardboard → Predicted: metal (0.9399999976158142)
# cardboard_339.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_272.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_333.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_068.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_056.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_149.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_139.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_041.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_089.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_188.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_343.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_325.jpg | True: cardboard → Predicted: trash (0.6399999856948853)
# cardboard_044.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_252.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_264.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_326.jpg | True: cardboard → Predicted: metal (0.7799999713897705)
# cardboard_141.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_356.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_100.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_181.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_265.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_338.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_166.jpg | True: cardboard → Predicted: plastic (0.9700000286102295)
# cardboard_013.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_245.jpg | True: cardboard → Predicted: trash (0.8700000047683716)
# cardboard_170.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_050.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_187.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_094.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_076.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_186.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_384.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_018.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_241.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_358.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_191.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_341.jpg | True: cardboard → Predicted: metal (0.9599999785423279)
# cardboard_249.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_216.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_381.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_267.jpg | True: cardboard → Predicted: trash (0.8700000047683716)
# cardboard_033.jpg | True: cardboard → Predicted: metal (0.9399999976158142)
# cardboard_235.jpg | True: cardboard → Predicted: metal (0.8100000023841858)
# cardboard_318.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_382.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_145.jpg | True: cardboard → Predicted: metal (0.7900000214576721)
# cardboard_152.jpg | True: cardboard → Predicted: metal (0.9399999976158142)
# cardboard_352.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_299.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_147.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_368.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_211.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_256.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_371.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_024.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_055.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_057.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_398.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_177.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_312.jpg | True: cardboard → Predicted: metal (0.9599999785423279)
# cardboard_395.jpg | True: cardboard → Predicted: trash (0.5299999713897705)
# cardboard_351.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_308.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_213.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_373.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_219.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_266.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_150.jpg | True: cardboard → Predicted: metal (0.9599999785423279)
# cardboard_155.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_370.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_070.jpg | True: cardboard → Predicted: metal (0.6299999952316284)
# cardboard_064.jpg | True: cardboard → Predicted: metal (0.5600000023841858)
# cardboard_327.jpg | True: cardboard → Predicted: metal (0.9200000166893005)
# cardboard_218.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_199.jpg | True: cardboard → Predicted: metal (0.6899999976158142)
# cardboard_069.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_123.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_054.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_174.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_088.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_295.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_314.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_244.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_403.jpg | True: cardboard → Predicted: metal (0.8600000143051147)
# cardboard_257.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_101.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_297.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_259.jpg | True: cardboard → Predicted: trash (1.0)
# cardboard_118.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_133.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_319.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_176.jpg | True: cardboard → Predicted: plastic (0.6000000238418579)
# cardboard_367.jpg | True: cardboard → Predicted: trash (0.9300000071525574)
# cardboard_315.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_158.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_190.jpg | True: cardboard → Predicted: trash (0.5400000214576721)
# cardboard_396.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_184.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_208.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_131.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_355.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_389.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_269.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_332.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_214.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_043.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_137.jpg | True: cardboard → Predicted: cardboard (0.6800000071525574)
# cardboard_122.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_003.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_119.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_357.jpg | True: cardboard → Predicted: metal (0.9599999785423279)
# cardboard_193.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_085.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_059.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_197.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_254.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_348.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_128.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_046.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_293.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_310.jpg | True: cardboard → Predicted: metal (0.9100000262260437)
# cardboard_104.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_226.jpg | True: cardboard → Predicted: metal (0.9399999976158142)
# cardboard_030.jpg | True: cardboard → Predicted: trash (0.9300000071525574)
# cardboard_258.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_109.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_092.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_110.jpg | True: cardboard → Predicted: metal (0.9200000166893005)
# cardboard_262.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_116.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_261.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_354.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_009.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_344.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_117.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_391.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_342.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_114.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_021.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_086.jpg | True: cardboard → Predicted: metal (0.7900000214576721)
# cardboard_198.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_182.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_048.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_001.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_237.jpg | True: cardboard → Predicted: metal (0.949999988079071)
# cardboard_163.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_120.jpg | True: cardboard → Predicted: metal (0.9100000262260437)
# cardboard_206.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_330.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_091.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_143.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_321.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_215.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_002.jpg | True: cardboard → Predicted: trash (0.8700000047683716)
# cardboard_016.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_331.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_161.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_067.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_172.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_399.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_019.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_203.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_309.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_004.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_012.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_093.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_171.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_217.jpg | True: cardboard → Predicted: trash (0.5099999904632568)
# cardboard_084.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_307.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_224.jpg | True: cardboard → Predicted: metal (0.8999999761581421)
# cardboard_350.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_337.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_280.jpg | True: cardboard → Predicted: metal (0.9300000071525574)
# cardboard_279.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_353.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_081.jpg | True: cardboard → Predicted: metal (0.8199999928474426)
# cardboard_028.jpg | True: cardboard → Predicted: metal (0.36000001430511475)
# cardboard_305.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_372.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_283.jpg | True: cardboard → Predicted: trash (0.5699999928474426)
# cardboard_124.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_290.jpg | True: cardboard → Predicted: metal (0.9200000166893005)
# cardboard_243.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_285.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_378.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_146.jpg | True: cardboard → Predicted: metal (0.949999988079071)
# cardboard_379.jpg | True: cardboard → Predicted: metal (0.9700000286102295)
# cardboard_183.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_051.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_136.jpg | True: cardboard → Predicted: metal (0.8899999856948853)
# cardboard_360.jpg | True: cardboard → Predicted: trash (0.6800000071525574)
# cardboard_362.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_207.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_090.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_347.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_274.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_240.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_361.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_071.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_080.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_336.jpg | True: cardboard → Predicted: trash (0.6800000071525574)
# cardboard_099.jpg | True: cardboard → Predicted: metal (0.8799999952316284)
# cardboard_234.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_365.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_375.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_334.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_180.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_374.jpg | True: cardboard → Predicted: trash (0.5199999809265137)
# cardboard_402.jpg | True: cardboard → Predicted: trash (0.8299999833106995)
# cardboard_209.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_390.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_271.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_210.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_388.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_098.jpg | True: cardboard → Predicted: metal (0.8100000023841858)
# cardboard_303.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_162.jpg | True: cardboard → Predicted: metal (0.5299999713897705)
# cardboard_047.jpg | True: cardboard → Predicted: trash (0.9900000095367432)
# cardboard_111.jpg | True: cardboard → Predicted: metal (0.5)
# cardboard_316.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_270.jpg | True: cardboard → Predicted: metal (0.9100000262260437)
# cardboard_276.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_311.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_126.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_096.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_320.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_401.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_063.jpg | True: cardboard → Predicted: metal (0.7799999713897705)
# cardboard_282.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_201.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_376.jpg | True: cardboard → Predicted: trash (0.8399999737739563)
# cardboard_292.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_142.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_066.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_349.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_236.jpg | True: cardboard → Predicted: trash (0.9599999785423279)
# cardboard_289.jpg | True: cardboard → Predicted: metal (0.8199999928474426)
# cardboard_300.jpg | True: cardboard → Predicted: trash (0.6600000262260437)
# cardboard_125.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_029.jpg | True: cardboard → Predicted: metal (0.9599999785423279)
# cardboard_010.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_179.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_253.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_107.jpg | True: cardboard → Predicted: trash (0.7099999785423279)
# cardboard_023.jpg | True: cardboard → Predicted: trash (1.0)
# cardboard_238.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_083.jpg | True: cardboard → Predicted: metal (0.9200000166893005)
# cardboard_239.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_015.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_020.jpg | True: cardboard → Predicted: metal (0.949999988079071)
# cardboard_227.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_095.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_132.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_160.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_127.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_151.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_247.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_364.jpg | True: cardboard → Predicted: trash (0.6399999856948853)
# cardboard_287.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_039.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_185.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_228.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_296.jpg | True: cardboard → Predicted: metal (0.9800000190734863)
# cardboard_087.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_014.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_065.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_223.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_106.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_156.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_025.jpg | True: cardboard → Predicted: trash (0.5400000214576721)
# cardboard_008.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_231.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_168.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_400.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_385.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_189.jpg | True: cardboard → Predicted: metal (0.6100000143051147)
# cardboard_229.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_053.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_363.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_011.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# cardboard_045.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_345.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_277.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_242.jpg | True: cardboard → Predicted: metal (0.5799999833106995)
# cardboard_027.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_138.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_173.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_273.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_195.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_062.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_220.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_359.jpg | True: cardboard → Predicted: metal (0.6800000071525574)
# cardboard_035.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_294.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_304.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_268.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_074.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_037.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_165.jpg | True: cardboard → Predicted: metal (1.0)
# cardboard_377.jpg | True: cardboard → Predicted: metal (0.9900000095367432)
# paper_315.jpg | True: paper → Predicted: metal (1.0)
# paper_096.jpg | True: paper → Predicted: metal (0.8700000047683716)
# paper_586.jpg | True: paper → Predicted: metal (0.6200000047683716)
# paper_017.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_005.jpg | True: paper → Predicted: metal (1.0)
# paper_046.jpg | True: paper → Predicted: metal (1.0)
# paper_105.jpg | True: paper → Predicted: trash (0.7400000095367432)
# paper_083.jpg | True: paper → Predicted: metal (1.0)
# paper_547.jpg | True: paper → Predicted: trash (0.7699999809265137)
# paper_325.jpg | True: paper → Predicted: metal (1.0)
# paper_159.jpg | True: paper → Predicted: metal (1.0)
# paper_206.jpg | True: paper → Predicted: metal (1.0)
# paper_454.jpg | True: paper → Predicted: metal (0.9700000286102295)
# paper_370.jpg | True: paper → Predicted: metal (0.7200000286102295)
# paper_482.jpg | True: paper → Predicted: trash (0.9900000095367432)
# paper_039.jpg | True: paper → Predicted: metal (1.0)
# paper_528.jpg | True: paper → Predicted: metal (1.0)
# paper_012.jpg | True: paper → Predicted: metal (1.0)
# paper_450.jpg | True: paper → Predicted: metal (1.0)
# paper_490.jpg | True: paper → Predicted: metal (1.0)
# paper_090.jpg | True: paper → Predicted: trash (0.9900000095367432)
# paper_415.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_505.jpg | True: paper → Predicted: metal (0.9300000071525574)
# paper_542.jpg | True: paper → Predicted: trash (0.949999988079071)
# paper_127.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_457.jpg | True: paper → Predicted: metal (0.6800000071525574)
# paper_207.jpg | True: paper → Predicted: metal (1.0)
# paper_433.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_172.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_125.jpg | True: paper → Predicted: trash (0.8199999928474426)
# paper_076.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_188.jpg | True: paper → Predicted: metal (1.0)
# paper_452.jpg | True: paper → Predicted: trash (0.7099999785423279)
# paper_045.jpg | True: paper → Predicted: metal (0.6100000143051147)
# paper_358.jpg | True: paper → Predicted: metal (0.75)
# paper_327.jpg | True: paper → Predicted: metal (1.0)
# paper_387.jpg | True: paper → Predicted: metal (0.9800000190734863)
# paper_319.jpg | True: paper → Predicted: metal (1.0)
# paper_111.jpg | True: paper → Predicted: metal (0.8700000047683716)
# paper_524.jpg | True: paper → Predicted: metal (1.0)
# paper_285.jpg | True: paper → Predicted: metal (1.0)
# paper_250.jpg | True: paper → Predicted: metal (1.0)
# paper_353.jpg | True: paper → Predicted: metal (1.0)
# paper_560.jpg | True: paper → Predicted: metal (1.0)
# paper_561.jpg | True: paper → Predicted: metal (1.0)
# paper_142.jpg | True: paper → Predicted: metal (1.0)
# paper_158.jpg | True: paper → Predicted: trash (0.7599999904632568)
# paper_337.jpg | True: paper → Predicted: metal (1.0)
# paper_124.jpg | True: paper → Predicted: metal (1.0)
# paper_208.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_020.jpg | True: paper → Predicted: metal (1.0)
# paper_468.jpg | True: paper → Predicted: metal (0.9399999976158142)
# paper_259.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_375.jpg | True: paper → Predicted: metal (0.699999988079071)
# paper_556.jpg | True: paper → Predicted: metal (1.0)
# paper_500.jpg | True: paper → Predicted: trash (0.49000000953674316)
# paper_057.jpg | True: paper → Predicted: metal (1.0)
# paper_577.jpg | True: paper → Predicted: metal (0.8600000143051147)
# paper_195.jpg | True: paper → Predicted: metal (1.0)
# paper_373.jpg | True: paper → Predicted: metal (1.0)
# paper_564.jpg | True: paper → Predicted: metal (1.0)
# paper_100.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_161.jpg | True: paper → Predicted: metal (1.0)
# paper_180.jpg | True: paper → Predicted: metal (0.7599999904632568)
# paper_551.jpg | True: paper → Predicted: metal (1.0)
# paper_238.jpg | True: paper → Predicted: metal (1.0)
# paper_585.jpg | True: paper → Predicted: metal (0.9399999976158142)
# paper_513.jpg | True: paper → Predicted: metal (1.0)
# paper_015.jpg | True: paper → Predicted: metal (0.8600000143051147)
# paper_409.jpg | True: paper → Predicted: metal (0.9800000190734863)
# paper_532.jpg | True: paper → Predicted: metal (1.0)
# paper_066.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_487.jpg | True: paper → Predicted: metal (0.5899999737739563)
# paper_414.jpg | True: paper → Predicted: trash (0.7799999713897705)
# paper_363.jpg | True: paper → Predicted: plastic (0.8299999833106995)
# paper_459.jpg | True: paper → Predicted: metal (1.0)
# paper_214.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_338.jpg | True: paper → Predicted: metal (1.0)
# paper_291.jpg | True: paper → Predicted: metal (0.9200000166893005)
# paper_190.jpg | True: paper → Predicted: metal (0.7200000286102295)
# paper_006.jpg | True: paper → Predicted: metal (1.0)
# paper_150.jpg | True: paper → Predicted: metal (1.0)
# paper_120.jpg | True: paper → Predicted: metal (1.0)
# paper_244.jpg | True: paper → Predicted: metal (0.9399999976158142)
# paper_355.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_398.jpg | True: paper → Predicted: trash (0.8700000047683716)
# paper_350.jpg | True: paper → Predicted: metal (1.0)
# paper_392.jpg | True: paper → Predicted: metal (1.0)
# paper_405.jpg | True: paper → Predicted: trash (0.7799999713897705)
# paper_287.jpg | True: paper → Predicted: metal (1.0)
# paper_257.jpg | True: paper → Predicted: metal (1.0)
# paper_123.jpg | True: paper → Predicted: metal (0.6200000047683716)
# paper_557.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_591.jpg | True: paper → Predicted: metal (0.8999999761581421)
# paper_070.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_530.jpg | True: paper → Predicted: metal (0.800000011920929)
# paper_559.jpg | True: paper → Predicted: metal (1.0)
# paper_126.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_504.jpg | True: paper → Predicted: metal (1.0)
# paper_583.jpg | True: paper → Predicted: trash (0.9399999976158142)
# paper_489.jpg | True: paper → Predicted: metal (0.5400000214576721)
# paper_426.jpg | True: paper → Predicted: metal (1.0)
# paper_030.jpg | True: paper → Predicted: trash (0.3799999952316284)
# paper_302.jpg | True: paper → Predicted: metal (1.0)
# paper_555.jpg | True: paper → Predicted: metal (1.0)
# paper_567.jpg | True: paper → Predicted: trash (0.7300000190734863)
# paper_093.jpg | True: paper → Predicted: metal (1.0)
# paper_154.jpg | True: paper → Predicted: metal (1.0)
# paper_541.jpg | True: paper → Predicted: metal (0.4099999964237213)
# paper_274.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_139.jpg | True: paper → Predicted: metal (1.0)
# paper_081.jpg | True: paper → Predicted: metal (1.0)
# paper_346.jpg | True: paper → Predicted: trash (0.47999998927116394)
# paper_571.jpg | True: paper → Predicted: metal (1.0)
# paper_182.jpg | True: paper → Predicted: metal (0.5600000023841858)
# paper_403.jpg | True: paper → Predicted: metal (1.0)
# paper_114.jpg | True: paper → Predicted: metal (1.0)
# paper_401.jpg | True: paper → Predicted: metal (0.9700000286102295)
# paper_470.jpg | True: paper → Predicted: metal (1.0)
# paper_365.jpg | True: paper → Predicted: metal (0.949999988079071)
# paper_299.jpg | True: paper → Predicted: metal (1.0)
# paper_223.jpg | True: paper → Predicted: metal (0.9399999976158142)
# paper_164.jpg | True: paper → Predicted: metal (1.0)
# paper_367.jpg | True: paper → Predicted: metal (0.47999998927116394)
# paper_306.jpg | True: paper → Predicted: metal (0.9800000190734863)
# paper_424.jpg | True: paper → Predicted: metal (1.0)
# paper_087.jpg | True: paper → Predicted: metal (0.9599999785423279)
# paper_171.jpg | True: paper → Predicted: metal (0.7599999904632568)
# paper_584.jpg | True: paper → Predicted: metal (1.0)
# paper_440.jpg | True: paper → Predicted: metal (1.0)
# paper_185.jpg | True: paper → Predicted: trash (0.6299999952316284)
# paper_366.jpg | True: paper → Predicted: metal (1.0)
# paper_115.jpg | True: paper → Predicted: metal (1.0)
# paper_455.jpg | True: paper → Predicted: metal (1.0)
# paper_108.jpg | True: paper → Predicted: metal (1.0)
# paper_137.jpg | True: paper → Predicted: metal (1.0)
# paper_131.jpg | True: paper → Predicted: metal (1.0)
# paper_224.jpg | True: paper → Predicted: metal (1.0)
# paper_369.jpg | True: paper → Predicted: metal (1.0)
# paper_077.jpg | True: paper → Predicted: metal (1.0)
# paper_279.jpg | True: paper → Predicted: metal (1.0)
# paper_445.jpg | True: paper → Predicted: metal (1.0)
# paper_065.jpg | True: paper → Predicted: trash (0.5099999904632568)
# paper_155.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_408.jpg | True: paper → Predicted: metal (0.7799999713897705)
# paper_307.jpg | True: paper → Predicted: metal (0.9200000166893005)
# paper_589.jpg | True: paper → Predicted: plastic (0.9100000262260437)
# paper_260.jpg | True: paper → Predicted: metal (0.8399999737739563)
# paper_069.jpg | True: paper → Predicted: metal (1.0)
# paper_539.jpg | True: paper → Predicted: plastic (0.5)
# paper_018.jpg | True: paper → Predicted: metal (1.0)
# paper_435.jpg | True: paper → Predicted: metal (1.0)
# paper_007.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_374.jpg | True: paper → Predicted: metal (0.9800000190734863)
# paper_281.jpg | True: paper → Predicted: metal (1.0)
# paper_498.jpg | True: paper → Predicted: metal (0.9700000286102295)
# paper_466.jpg | True: paper → Predicted: metal (1.0)
# paper_192.jpg | True: paper → Predicted: metal (0.9300000071525574)
# paper_396.jpg | True: paper → Predicted: metal (1.0)
# paper_003.jpg | True: paper → Predicted: metal (1.0)
# paper_062.jpg | True: paper → Predicted: metal (1.0)
# paper_402.jpg | True: paper → Predicted: metal (1.0)
# paper_044.jpg | True: paper → Predicted: metal (0.7900000214576721)
# paper_191.jpg | True: paper → Predicted: metal (1.0)
# paper_210.jpg | True: paper → Predicted: metal (1.0)
# paper_420.jpg | True: paper → Predicted: metal (0.7900000214576721)
# paper_463.jpg | True: paper → Predicted: metal (1.0)
# paper_243.jpg | True: paper → Predicted: metal (1.0)
# paper_592.jpg | True: paper → Predicted: metal (0.6399999856948853)
# paper_107.jpg | True: paper → Predicted: metal (1.0)
# paper_389.jpg | True: paper → Predicted: metal (1.0)
# paper_438.jpg | True: paper → Predicted: metal (1.0)
# paper_273.jpg | True: paper → Predicted: metal (1.0)
# paper_202.jpg | True: paper → Predicted: trash (0.4099999964237213)
# paper_436.jpg | True: paper → Predicted: metal (1.0)
# paper_464.jpg | True: paper → Predicted: metal (1.0)
# paper_239.jpg | True: paper → Predicted: metal (0.5)
# paper_170.jpg | True: paper → Predicted: metal (1.0)
# paper_016.jpg | True: paper → Predicted: metal (0.9599999785423279)
# paper_515.jpg | True: paper → Predicted: metal (1.0)
# paper_393.jpg | True: paper → Predicted: metal (0.9800000190734863)
# paper_343.jpg | True: paper → Predicted: metal (1.0)
# paper_235.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_118.jpg | True: paper → Predicted: metal (0.4699999988079071)
# paper_309.jpg | True: paper → Predicted: metal (1.0)
# paper_351.jpg | True: paper → Predicted: metal (0.9399999976158142)
# paper_269.jpg | True: paper → Predicted: metal (1.0)
# paper_469.jpg | True: paper → Predicted: metal (1.0)
# paper_248.jpg | True: paper → Predicted: trash (0.9399999976158142)
# paper_196.jpg | True: paper → Predicted: metal (0.5)
# paper_160.jpg | True: paper → Predicted: trash (0.9399999976158142)
# paper_286.jpg | True: paper → Predicted: metal (0.9599999785423279)
# paper_317.jpg | True: paper → Predicted: plastic (0.9300000071525574)
# paper_157.jpg | True: paper → Predicted: trash (0.9100000262260437)
# paper_217.jpg | True: paper → Predicted: metal (1.0)
# paper_499.jpg | True: paper → Predicted: metal (1.0)
# paper_578.jpg | True: paper → Predicted: metal (1.0)
# paper_104.jpg | True: paper → Predicted: metal (1.0)
# paper_384.jpg | True: paper → Predicted: metal (1.0)
# paper_086.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_272.jpg | True: paper → Predicted: metal (1.0)
# paper_027.jpg | True: paper → Predicted: metal (1.0)
# paper_079.jpg | True: paper → Predicted: metal (1.0)
# paper_446.jpg | True: paper → Predicted: metal (1.0)
# paper_064.jpg | True: paper → Predicted: metal (0.6800000071525574)
# paper_483.jpg | True: paper → Predicted: metal (1.0)
# paper_200.jpg | True: paper → Predicted: metal (1.0)
# paper_226.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_422.jpg | True: paper → Predicted: metal (0.6800000071525574)
# paper_089.jpg | True: paper → Predicted: trash (1.0)
# paper_565.jpg | True: paper → Predicted: metal (1.0)
# paper_298.jpg | True: paper → Predicted: metal (1.0)
# paper_349.jpg | True: paper → Predicted: metal (1.0)
# paper_479.jpg | True: paper → Predicted: metal (1.0)
# paper_321.jpg | True: paper → Predicted: metal (1.0)
# paper_332.jpg | True: paper → Predicted: trash (0.9700000286102295)
# paper_580.jpg | True: paper → Predicted: metal (1.0)
# paper_529.jpg | True: paper → Predicted: plastic (0.550000011920929)
# paper_476.jpg | True: paper → Predicted: metal (1.0)
# paper_400.jpg | True: paper → Predicted: trash (0.49000000953674316)
# paper_091.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_352.jpg | True: paper → Predicted: metal (1.0)
# paper_119.jpg | True: paper → Predicted: metal (1.0)
# paper_493.jpg | True: paper → Predicted: trash (0.8999999761581421)
# paper_144.jpg | True: paper → Predicted: metal (0.9200000166893005)
# paper_540.jpg | True: paper → Predicted: metal (1.0)
# paper_368.jpg | True: paper → Predicted: metal (1.0)
# paper_538.jpg | True: paper → Predicted: metal (1.0)
# paper_271.jpg | True: paper → Predicted: trash (0.8799999952316284)
# paper_473.jpg | True: paper → Predicted: metal (1.0)
# paper_008.jpg | True: paper → Predicted: trash (0.9599999785423279)
# paper_061.jpg | True: paper → Predicted: trash (0.7400000095367432)
# paper_134.jpg | True: paper → Predicted: metal (1.0)
# paper_193.jpg | True: paper → Predicted: trash (0.4699999988079071)
# paper_313.jpg | True: paper → Predicted: metal (1.0)
# paper_094.jpg | True: paper → Predicted: metal (0.8999999761581421)
# paper_310.jpg | True: paper → Predicted: trash (0.9900000095367432)
# paper_229.jpg | True: paper → Predicted: metal (1.0)
# paper_173.jpg | True: paper → Predicted: metal (0.9700000286102295)
# paper_512.jpg | True: paper → Predicted: metal (0.8799999952316284)
# paper_441.jpg | True: paper → Predicted: metal (0.7099999785423279)
# paper_549.jpg | True: paper → Predicted: metal (1.0)
# paper_397.jpg | True: paper → Predicted: metal (1.0)
# paper_380.jpg | True: paper → Predicted: metal (0.9700000286102295)
# paper_523.jpg | True: paper → Predicted: metal (1.0)
# paper_478.jpg | True: paper → Predicted: metal (1.0)
# paper_056.jpg | True: paper → Predicted: metal (1.0)
# paper_495.jpg | True: paper → Predicted: metal (0.9700000286102295)
# paper_033.jpg | True: paper → Predicted: metal (1.0)
# paper_574.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_521.jpg | True: paper → Predicted: metal (1.0)
# paper_501.jpg | True: paper → Predicted: metal (1.0)
# paper_237.jpg | True: paper → Predicted: metal (1.0)
# paper_187.jpg | True: paper → Predicted: metal (1.0)
# paper_443.jpg | True: paper → Predicted: metal (0.6299999952316284)
# paper_494.jpg | True: paper → Predicted: trash (0.6700000166893005)
# paper_013.jpg | True: paper → Predicted: metal (1.0)
# paper_418.jpg | True: paper → Predicted: metal (1.0)
# paper_169.jpg | True: paper → Predicted: metal (1.0)
# paper_041.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_010.jpg | True: paper → Predicted: metal (0.9700000286102295)
# paper_176.jpg | True: paper → Predicted: metal (0.9300000071525574)
# paper_548.jpg | True: paper → Predicted: metal (1.0)
# paper_204.jpg | True: paper → Predicted: paper (0.5899999737739563)
# paper_290.jpg | True: paper → Predicted: metal (1.0)
# paper_304.jpg | True: paper → Predicted: metal (0.949999988079071)
# paper_078.jpg | True: paper → Predicted: metal (1.0)
# paper_267.jpg | True: paper → Predicted: metal (0.9800000190734863)
# paper_474.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_034.jpg | True: paper → Predicted: metal (1.0)
# paper_497.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_442.jpg | True: paper → Predicted: metal (1.0)
# paper_339.jpg | True: paper → Predicted: metal (0.9700000286102295)
# paper_289.jpg | True: paper → Predicted: metal (1.0)
# paper_151.jpg | True: paper → Predicted: plastic (0.7200000286102295)
# paper_292.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_525.jpg | True: paper → Predicted: metal (1.0)
# paper_276.jpg | True: paper → Predicted: plastic (1.0)
# paper_255.jpg | True: paper → Predicted: metal (1.0)
# paper_423.jpg | True: paper → Predicted: metal (0.9200000166893005)
# paper_502.jpg | True: paper → Predicted: metal (1.0)
# paper_221.jpg | True: paper → Predicted: metal (1.0)
# paper_340.jpg | True: paper → Predicted: metal (1.0)
# paper_356.jpg | True: paper → Predicted: metal (1.0)
# paper_110.jpg | True: paper → Predicted: trash (0.7400000095367432)
# paper_153.jpg | True: paper → Predicted: trash (0.949999988079071)
# paper_268.jpg | True: paper → Predicted: plastic (0.8199999928474426)
# paper_416.jpg | True: paper → Predicted: metal (1.0)
# paper_277.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_510.jpg | True: paper → Predicted: metal (1.0)
# paper_219.jpg | True: paper → Predicted: metal (1.0)
# paper_404.jpg | True: paper → Predicted: metal (1.0)
# paper_175.jpg | True: paper → Predicted: metal (1.0)
# paper_178.jpg | True: paper → Predicted: metal (1.0)
# paper_258.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_544.jpg | True: paper → Predicted: metal (1.0)
# paper_278.jpg | True: paper → Predicted: metal (0.9200000166893005)
# paper_514.jpg | True: paper → Predicted: metal (0.9200000166893005)
# paper_181.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_254.jpg | True: paper → Predicted: metal (1.0)
# paper_253.jpg | True: paper → Predicted: metal (1.0)
# paper_385.jpg | True: paper → Predicted: metal (0.8299999833106995)
# paper_475.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_233.jpg | True: paper → Predicted: metal (1.0)
# paper_376.jpg | True: paper → Predicted: metal (0.38999998569488525)
# paper_311.jpg | True: paper → Predicted: trash (0.6299999952316284)
# paper_434.jpg | True: paper → Predicted: trash (0.5799999833106995)
# paper_308.jpg | True: paper → Predicted: metal (1.0)
# paper_167.jpg | True: paper → Predicted: metal (1.0)
# paper_407.jpg | True: paper → Predicted: metal (1.0)
# paper_472.jpg | True: paper → Predicted: metal (1.0)
# paper_406.jpg | True: paper → Predicted: metal (1.0)
# paper_132.jpg | True: paper → Predicted: metal (0.8700000047683716)
# paper_550.jpg | True: paper → Predicted: metal (1.0)
# paper_335.jpg | True: paper → Predicted: metal (1.0)
# paper_465.jpg | True: paper → Predicted: metal (1.0)
# paper_491.jpg | True: paper → Predicted: trash (0.5899999737739563)
# paper_462.jpg | True: paper → Predicted: metal (1.0)
# paper_344.jpg | True: paper → Predicted: metal (0.8299999833106995)
# paper_138.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_231.jpg | True: paper → Predicted: metal (1.0)
# paper_203.jpg | True: paper → Predicted: metal (1.0)
# paper_394.jpg | True: paper → Predicted: metal (1.0)
# paper_303.jpg | True: paper → Predicted: metal (1.0)
# paper_080.jpg | True: paper → Predicted: metal (1.0)
# paper_019.jpg | True: paper → Predicted: metal (1.0)
# paper_305.jpg | True: paper → Predicted: metal (0.9800000190734863)
# paper_533.jpg | True: paper → Predicted: trash (0.9900000095367432)
# paper_216.jpg | True: paper → Predicted: metal (1.0)
# paper_265.jpg | True: paper → Predicted: metal (0.8500000238418579)
# paper_148.jpg | True: paper → Predicted: metal (1.0)
# paper_049.jpg | True: paper → Predicted: metal (0.550000011920929)
# paper_101.jpg | True: paper → Predicted: metal (1.0)
# paper_554.jpg | True: paper → Predicted: metal (1.0)
# paper_053.jpg | True: paper → Predicted: metal (1.0)
# paper_117.jpg | True: paper → Predicted: metal (0.7799999713897705)
# paper_395.jpg | True: paper → Predicted: metal (0.9700000286102295)
# paper_503.jpg | True: paper → Predicted: metal (0.9900000095367432)
# paper_212.jpg | True: paper → Predicted: metal (0.7400000095367432)
# paper_320.jpg | True: paper → Predicted: metal (1.0)
# paper_562.jpg | True: paper → Predicted: metal (0.4300000071525574)
# paper_594.jpg | True: paper → Predicted: metal (0.7200000286102295)
# paper_047.jpg | True: paper → Predicted: metal (1.0)
# paper_471.jpg | True: paper → Predicted: metal (0.9599999785423279)
# paper_230.jpg | True: paper → Predicted: metal (1.0)
# ...
# glass_283.jpg | True: glass → Predicted: trash (0.949999988079071)
# glass_426.jpg | True: glass → Predicted: trash (0.7099999785423279)
# glass_362.jpg | True: glass → Predicted: metal (0.949999988079071)
# glass_299.jpg | True: glass → Predicted: metal (0.9599999785423279)
# glass_412.jpg | True: glass → Predicted: trash (0.949999988079071)
# glass_056.jpg | True: glass → Predicted: trash (0.6000000238418579)
# glass_054.jpg | True: glass → Predicted: metal (1.0)
# glass_226.jpg | True: glass → Predicted: metal (1.0)
# glass_253.jpg | True: glass → Predicted: metal (0.9100000262260437)
# glass_218.jpg | True: glass → Predicted: metal (0.9300000071525574)
# glass_036.jpg | True: glass → Predicted: metal (0.949999988079071)
# glass_246.jpg | True: glass → Predicted: metal (0.7300000190734863)
# glass_364.jpg | True: glass → Predicted: trash (0.9800000190734863)
# glass_211.jpg | True: glass → Predicted: metal (1.0)
# glass_139.jpg | True: glass → Predicted: trash (1.0)
# glass_208.jpg | True: glass → Predicted: metal (1.0)
# glass_266.jpg | True: glass → Predicted: plastic (0.7200000286102295)
# glass_026.jpg | True: glass → Predicted: metal (1.0)
# glass_255.jpg | True: glass → Predicted: metal (0.6000000238418579)
# glass_476.jpg | True: glass → Predicted: metal (0.9599999785423279)
# glass_392.jpg | True: glass → Predicted: trash (0.9700000286102295)
# glass_377.jpg | True: glass → Predicted: metal (0.9900000095367432)
# glass_374.jpg | True: glass → Predicted: trash (0.949999988079071)
# glass_498.jpg | True: glass → Predicted: trash (0.9900000095367432)
# glass_330.jpg | True: glass → Predicted: metal (1.0)
# glass_173.jpg | True: glass → Predicted: metal (0.800000011920929)
# glass_296.jpg | True: glass → Predicted: trash (0.8799999952316284)
# glass_040.jpg | True: glass → Predicted: trash (0.9900000095367432)
# glass_358.jpg | True: glass → Predicted: trash (1.0)
# glass_124.jpg | True: glass → Predicted: metal (0.8999999761581421)
# glass_268.jpg | True: glass → Predicted: paper (0.7799999713897705)
# glass_427.jpg | True: glass → Predicted: trash (1.0)
# glass_464.jpg | True: glass → Predicted: cardboard (0.6499999761581421)
# glass_295.jpg | True: glass → Predicted: trash (0.9300000071525574)
# glass_010.jpg | True: glass → Predicted: trash (0.9900000095367432)
# glass_444.jpg | True: glass → Predicted: metal (1.0)
# glass_045.jpg | True: glass → Predicted: metal (0.6000000238418579)
# glass_430.jpg | True: glass → Predicted: metal (1.0)
# glass_254.jpg | True: glass → Predicted: metal (0.5299999713897705)
# glass_408.jpg | True: glass → Predicted: metal (0.9900000095367432)
# glass_271.jpg | True: glass → Predicted: metal (1.0)
# glass_117.jpg | True: glass → Predicted: metal (1.0)
# glass_402.jpg | True: glass → Predicted: metal (0.6399999856948853)
# glass_180.jpg | True: glass → Predicted: metal (0.9399999976158142)
# glass_095.jpg | True: glass → Predicted: metal (0.9200000166893005)
# glass_441.jpg | True: glass → Predicted: metal (0.800000011920929)
# glass_131.jpg | True: glass → Predicted: metal (0.6800000071525574)
# glass_078.jpg | True: glass → Predicted: trash (0.4699999988079071)
# glass_401.jpg | True: glass → Predicted: plastic (1.0)
# glass_262.jpg | True: glass → Predicted: trash (0.9300000071525574)
# glass_416.jpg | True: glass → Predicted: metal (0.9900000095367432)
# glass_329.jpg | True: glass → Predicted: metal (0.49000000953674316)
# glass_225.jpg | True: glass → Predicted: metal (0.8299999833106995)
# glass_338.jpg | True: glass → Predicted: trash (0.550000011920929)
# glass_070.jpg | True: glass → Predicted: metal (0.5400000214576721)
# glass_347.jpg | True: glass → Predicted: trash (0.8899999856948853)
# glass_090.jpg | True: glass → Predicted: metal (0.9900000095367432)
# glass_243.jpg | True: glass → Predicted: metal (0.9599999785423279)
# glass_027.jpg | True: glass → Predicted: metal (0.9100000262260437)
# glass_405.jpg | True: glass → Predicted: plastic (0.47999998927116394)
# glass_191.jpg | True: glass → Predicted: metal (0.9700000286102295)
# glass_389.jpg | True: glass → Predicted: trash (0.9900000095367432)
# glass_085.jpg | True: glass → Predicted: metal (0.8299999833106995)
# glass_385.jpg | True: glass → Predicted: metal (1.0)
# glass_437.jpg | True: glass → Predicted: glass (0.5799999833106995)
# glass_479.jpg | True: glass → Predicted: trash (0.9599999785423279)
# glass_015.jpg | True: glass → Predicted: metal (0.9900000095367432)
# glass_501.jpg | True: glass → Predicted: metal (0.8600000143051147)
# glass_435.jpg | True: glass → Predicted: trash (1.0)
# glass_240.jpg | True: glass → Predicted: trash (0.9900000095367432)
# glass_230.jpg | True: glass → Predicted: metal (0.9399999976158142)
# glass_179.jpg | True: glass → Predicted: metal (1.0)
# glass_421.jpg | True: glass → Predicted: metal (0.9700000286102295)
# glass_086.jpg | True: glass → Predicted: trash (1.0)
# glass_340.jpg | True: glass → Predicted: trash (0.5600000023841858)
# glass_232.jpg | True: glass → Predicted: trash (0.9200000166893005)
# glass_396.jpg | True: glass → Predicted: trash (0.6100000143051147)
# glass_433.jpg | True: glass → Predicted: trash (1.0)
# glass_047.jpg | True: glass → Predicted: metal (0.9300000071525574)
# glass_394.jpg | True: glass → Predicted: metal (0.8999999761581421)
# glass_229.jpg | True: glass → Predicted: metal (0.9700000286102295)
# glass_415.jpg | True: glass → Predicted: metal (1.0)
# glass_018.jpg | True: glass → Predicted: trash (0.7300000190734863)
# glass_132.jpg | True: glass → Predicted: metal (1.0)
# glass_115.jpg | True: glass → Predicted: metal (1.0)
# glass_386.jpg | True: glass → Predicted: trash (0.9700000286102295)
# glass_456.jpg | True: glass → Predicted: metal (0.9900000095367432)
# glass_244.jpg | True: glass → Predicted: metal (0.5)
# glass_474.jpg | True: glass → Predicted: metal (1.0)
# glass_315.jpg | True: glass → Predicted: trash (1.0)
# glass_234.jpg | True: glass → Predicted: metal (0.9900000095367432)
# glass_209.jpg | True: glass → Predicted: metal (0.7900000214576721)
# glass_114.jpg | True: glass → Predicted: metal (0.5299999713897705)
# glass_494.jpg | True: glass → Predicted: metal (1.0)
# glass_035.jpg | True: glass → Predicted: trash (0.9900000095367432)
# glass_122.jpg | True: glass → Predicted: metal (0.9399999976158142)
# glass_011.jpg | True: glass → Predicted: metal (0.6899999976158142)
# glass_202.jpg | True: glass → Predicted: trash (0.949999988079071)
# glass_126.jpg | True: glass → Predicted: metal (0.9900000095367432)
# glass_249.jpg | True: glass → Predicted: metal (1.0)
# glass_169.jpg | True: glass → Predicted: metal (1.0)
# glass_100.jpg | True: glass → Predicted: metal (1.0)
# glass_379.jpg | True: glass → Predicted: trash (0.5199999809265137)
# glass_025.jpg | True: glass → Predicted: metal (0.9700000286102295)
# glass_072.jpg | True: glass → Predicted: trash (0.8700000047683716)
# glass_005.jpg | True: glass → Predicted: metal (0.8899999856948853)
# glass_410.jpg | True: glass → Predicted: metal (0.8999999761581421)
# glass_478.jpg | True: glass → Predicted: metal (0.9900000095367432)
# glass_103.jpg | True: glass → Predicted: metal (0.9100000262260437)
# glass_023.jpg | True: glass → Predicted: trash (0.9200000166893005)
# glass_157.jpg | True: glass → Predicted: trash (0.9700000286102295)
# glass_306.jpg | True: glass → Predicted: metal (0.9800000190734863)
# glass_316.jpg | True: glass → Predicted: trash (0.5899999737739563)
# glass_251.jpg | True: glass → Predicted: trash (0.9800000190734863)
# glass_256.jpg | True: glass → Predicted: trash (0.5299999713897705)
# glass_348.jpg | True: glass → Predicted: metal (0.8299999833106995)
# trash_026.jpg | True: trash → Predicted: trash (0.5799999833106995)
# trash_032.jpg | True: trash → Predicted: trash (1.0)
# trash_014.jpg | True: trash → Predicted: metal (1.0)
# trash_130.jpg | True: trash → Predicted: metal (1.0)
# trash_100.jpg | True: trash → Predicted: trash (0.9399999976158142)
# trash_060.jpg | True: trash → Predicted: metal (0.9100000262260437)
# trash_111.jpg | True: trash → Predicted: metal (1.0)
# trash_038.jpg | True: trash → Predicted: trash (0.9800000190734863)
# trash_121.jpg | True: trash → Predicted: metal (0.9700000286102295)
# trash_079.jpg | True: trash → Predicted: metal (1.0)
# trash_013.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_020.jpg | True: trash → Predicted: metal (0.5699999928474426)
# trash_093.jpg | True: trash → Predicted: trash (0.8700000047683716)
# trash_066.jpg | True: trash → Predicted: metal (0.6299999952316284)
# trash_096.jpg | True: trash → Predicted: trash (1.0)
# trash_064.jpg | True: trash → Predicted: metal (0.8299999833106995)
# trash_112.jpg | True: trash → Predicted: metal (1.0)
# trash_092.jpg | True: trash → Predicted: trash (0.5600000023841858)
# trash_049.jpg | True: trash → Predicted: trash (0.7200000286102295)
# trash_117.jpg | True: trash → Predicted: trash (1.0)
# trash_050.jpg | True: trash → Predicted: trash (0.949999988079071)
# trash_048.jpg | True: trash → Predicted: trash (0.5899999737739563)
# trash_051.jpg | True: trash → Predicted: metal (0.9599999785423279)
# trash_023.jpg | True: trash → Predicted: metal (1.0)
# trash_009.jpg | True: trash → Predicted: metal (1.0)
# trash_004.jpg | True: trash → Predicted: metal (1.0)
# trash_031.jpg | True: trash → Predicted: metal (0.7400000095367432)
# trash_114.jpg | True: trash → Predicted: metal (1.0)
# trash_005.jpg | True: trash → Predicted: trash (0.4699999988079071)
# trash_088.jpg | True: trash → Predicted: metal (1.0)
# trash_101.jpg | True: trash → Predicted: trash (1.0)
# trash_028.jpg | True: trash → Predicted: trash (0.7799999713897705)
# trash_011.jpg | True: trash → Predicted: metal (1.0)
# trash_086.jpg | True: trash → Predicted: trash (0.9399999976158142)
# trash_043.jpg | True: trash → Predicted: metal (0.8700000047683716)
# trash_083.jpg | True: trash → Predicted: metal (1.0)
# trash_132.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_033.jpg | True: trash → Predicted: trash (0.8299999833106995)
# trash_010.jpg | True: trash → Predicted: metal (0.9800000190734863)
# trash_119.jpg | True: trash → Predicted: trash (0.9399999976158142)
# trash_087.jpg | True: trash → Predicted: trash (0.9900000095367432)
# trash_091.jpg | True: trash → Predicted: trash (0.9700000286102295)
# trash_039.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_057.jpg | True: trash → Predicted: metal (0.8199999928474426)
# trash_136.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_021.jpg | True: trash → Predicted: metal (1.0)
# trash_072.jpg | True: trash → Predicted: trash (0.5099999904632568)
# trash_081.jpg | True: trash → Predicted: metal (1.0)
# trash_063.jpg | True: trash → Predicted: metal (0.9100000262260437)
# trash_069.jpg | True: trash → Predicted: trash (0.7699999809265137)
# trash_122.jpg | True: trash → Predicted: metal (1.0)
# trash_109.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_008.jpg | True: trash → Predicted: trash (1.0)
# trash_073.jpg | True: trash → Predicted: trash (0.800000011920929)
# trash_046.jpg | True: trash → Predicted: metal (1.0)
# trash_104.jpg | True: trash → Predicted: metal (0.9800000190734863)
# trash_070.jpg | True: trash → Predicted: metal (1.0)
# trash_129.jpg | True: trash → Predicted: metal (1.0)
# trash_041.jpg | True: trash → Predicted: metal (0.9800000190734863)
# trash_077.jpg | True: trash → Predicted: trash (0.8100000023841858)
# trash_078.jpg | True: trash → Predicted: trash (0.9800000190734863)
# trash_054.jpg | True: trash → Predicted: trash (0.6000000238418579)
# trash_024.jpg | True: trash → Predicted: metal (1.0)
# trash_056.jpg | True: trash → Predicted: metal (0.5099999904632568)
# trash_047.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_120.jpg | True: trash → Predicted: trash (0.5899999737739563)
# trash_053.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_106.jpg | True: trash → Predicted: trash (0.6100000143051147)
# trash_074.jpg | True: trash → Predicted: trash (1.0)
# trash_025.jpg | True: trash → Predicted: trash (0.9300000071525574)
# trash_022.jpg | True: trash → Predicted: trash (0.9399999976158142)
# trash_099.jpg | True: trash → Predicted: trash (1.0)
# trash_098.jpg | True: trash → Predicted: metal (1.0)
# trash_108.jpg | True: trash → Predicted: trash (0.8399999737739563)
# trash_034.jpg | True: trash → Predicted: trash (0.8799999952316284)
# trash_012.jpg | True: trash → Predicted: trash (0.5299999713897705)
# trash_065.jpg | True: trash → Predicted: trash (0.9900000095367432)
# trash_126.jpg | True: trash → Predicted: metal (1.0)
# trash_137.jpg | True: trash → Predicted: metal (1.0)
# trash_029.jpg | True: trash → Predicted: metal (1.0)
# trash_076.jpg | True: trash → Predicted: trash (0.9300000071525574)
# trash_042.jpg | True: trash → Predicted: trash (0.9599999785423279)
# trash_003.jpg | True: trash → Predicted: metal (1.0)
# trash_030.jpg | True: trash → Predicted: trash (0.8999999761581421)
# trash_105.jpg | True: trash → Predicted: metal (1.0)
# trash_110.jpg | True: trash → Predicted: metal (0.8600000143051147)
# trash_125.jpg | True: trash → Predicted: metal (1.0)
# trash_102.jpg | True: trash → Predicted: trash (0.8999999761581421)
# trash_015.jpg | True: trash → Predicted: trash (0.8999999761581421)
# trash_133.jpg | True: trash → Predicted: metal (1.0)
# trash_124.jpg | True: trash → Predicted: metal (1.0)
# trash_107.jpg | True: trash → Predicted: metal (0.9800000190734863)
# trash_019.jpg | True: trash → Predicted: metal (1.0)
# trash_084.jpg | True: trash → Predicted: metal (0.9599999785423279)
# trash_055.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_089.jpg | True: trash → Predicted: metal (1.0)
# trash_017.jpg | True: trash → Predicted: trash (0.9599999785423279)
# trash_058.jpg | True: trash → Predicted: metal (1.0)
# trash_040.jpg | True: trash → Predicted: metal (1.0)
# trash_095.jpg | True: trash → Predicted: metal (0.699999988079071)
# trash_090.jpg | True: trash → Predicted: plastic (0.7900000214576721)
# trash_001.jpg | True: trash → Predicted: trash (1.0)
# trash_067.jpg | True: trash → Predicted: metal (0.9599999785423279)
# trash_071.jpg | True: trash → Predicted: trash (0.9599999785423279)
# trash_062.jpg | True: trash → Predicted: metal (0.7300000190734863)
# trash_094.jpg | True: trash → Predicted: metal (1.0)
# trash_123.jpg | True: trash → Predicted: metal (1.0)
# trash_085.jpg | True: trash → Predicted: metal (1.0)
# trash_061.jpg | True: trash → Predicted: metal (0.9399999976158142)
# trash_045.jpg | True: trash → Predicted: trash (0.8799999952316284)
# trash_115.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_116.jpg | True: trash → Predicted: metal (1.0)
# trash_016.jpg | True: trash → Predicted: metal (0.36000001430511475)
# trash_113.jpg | True: trash → Predicted: metal (1.0)
# trash_037.jpg | True: trash → Predicted: trash (0.9900000095367432)
# trash_134.jpg | True: trash → Predicted: metal (1.0)
# trash_127.jpg | True: trash → Predicted: metal (1.0)
# trash_035.jpg | True: trash → Predicted: metal (1.0)
# trash_036.jpg | True: trash → Predicted: trash (0.7799999713897705)
# trash_118.jpg | True: trash → Predicted: metal (0.9599999785423279)
# trash_131.jpg | True: trash → Predicted: metal (1.0)
# trash_097.jpg | True: trash → Predicted: metal (0.6800000071525574)
# trash_068.jpg | True: trash → Predicted: metal (0.9599999785423279)
# trash_128.jpg | True: trash → Predicted: metal (1.0)
# trash_018.jpg | True: trash → Predicted: metal (1.0)
# trash_002.jpg | True: trash → Predicted: trash (1.0)
# trash_082.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_007.jpg | True: trash → Predicted: metal (1.0)
# trash_006.jpg | True: trash → Predicted: metal (0.9599999785423279)
# trash_080.jpg | True: trash → Predicted: trash (0.8199999928474426)
# trash_135.jpg | True: trash → Predicted: metal (1.0)
# trash_059.jpg | True: trash → Predicted: metal (0.9900000095367432)
# trash_052.jpg | True: trash → Predicted: trash (0.9599999785423279)
# trash_075.jpg | True: trash → Predicted: trash (0.7799999713897705)
# trash_103.jpg | True: trash → Predicted: metal (0.8299999833106995)
# trash_044.jpg | True: trash → Predicted: metal (0.6800000071525574)
# trash_027.jpg | True: trash → Predicted: metal (0.9900000095367432)

# %% [markdown]
# Part 4: Accuracy metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(val_data)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_data.classes

print("Classification Report:")
print(classification_report(y_true, y_pred_classes, target_names=class_names))

print("Confusion Matrix:")
print(confusion_matrix(y_true, y_pred_classes))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 443ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#    cardboard       0.39      0.09      0.14        80
#        glass       0.00      0.00      0.00       100
#        metal       0.16      0.71      0.26        82
#        paper       0.00      0.00      0.00       118
#      plastic       0.16      0.03      0.05        96
#        trash       0.04      0.15      0.07        27
#
#     accuracy                           0.14       503
#    macro avg       0.12      0.16      0.09       503
# weighted avg       0.12      0.14      0.08       503
#
# Confusion Matrix:
# [[ 7  0 54  1  3 15]
#  [ 2  0 73  0  6 19]
#  [ 2  0 58  1  2 19]
#  [ 2  0 86  0  5 25]
#  [ 3  0 80  0  3 10]
#  [ 2  0 21  0  0  4]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
